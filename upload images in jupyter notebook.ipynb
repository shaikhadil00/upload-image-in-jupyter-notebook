# %% [markdown]
# # How to upload images in jupyter notebook
# steps:
# 1.Markdown
# 2.Edit
# 3.Insert Images
# 4.choose file
# 5.select images
# 6.run

# %% [markdown]
# ![bycycle.avif](attachment:bycycle.avif)
